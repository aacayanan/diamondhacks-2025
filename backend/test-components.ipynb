# %%
import scipy.signal as ss
import numpy as np

# %%
r_shoulder_data = [0.3057, 0.2974, 0.2833, 0.2659, 0.2505, 0.2407, 0.238, 0.2446, 0.249, 0.2642, 0.2808, 0.2843, 0.2801,
                   0.2652, 0.2528, 0.2449, 0.2429, 0.2452, 0.2474, 0.2623, 0.2796, 0.2877, 0.284
                   6, 0.2792, 0.2658, 0.2545, 0.2475, 0.2453, 0.2466, 0.2525, 0.2696, 0.2829, 0.2853, 0.2843, 0.2743,
                   0.2569, 0.244, 0.2411, 0.243, 0.2452, 0.264, 0.2809, 0.2856, 0.2825, 0.2734, 0.25
                   84, 0.2463, 0.2415, 0.241, 0.242, 0.2545, 0.274, 0.2818, 0.2802, 0.2767, 0.264, 0.2487, 0.2408,
                   0.2401, 0.2419, 0.245, 0.2658, 0.284, 0.2863, 0.2826, 0.275, 0.2609, 0.2467, 0.2393,
                   0.2396, 0.2415, 0.2532, 0.2707, 0.2828, 0.2807, 0.2786, 0.2628, 0.249, 0.2389, 0.2357, 0.2373,
                   0.2408, 0.2584, 0.2728, 0.2743, 0.2733, 0.2618, 0.2443, 0.2332, 0.2308, 0.2323, 0.23
                   38, 0.2549, 0.2724, 0.2768, 0.2736, 0.2673, 0.2508, 0.2365, 0.2327, 0.232, 0.2335, 0.2485, 0.2682,
                   0.2733, 0.2707, 0.2639, 0.2482, 0.2376, 0.2323, 0.2337, 0.2349, 0.2522, 0.2665, 0
                   .269, 0.2671, 0.2559, 0.2437, 0.233, 0.2299, 0.2318, 0.2346, 0.2538, 0.2695, 0.2748, 0.2724, 0.2666,
                   0.2487, 0.2356, 0.2287, 0.2308, 0.232, 0.2497, 0.2692, 0.2772, 0.2743, 0.2719,
                   0.2641, 0.2499, 0.2433, 0.243, 0.2437, 0.2557, 0.2758, 0.2805, 0.2772, 0.2702, 0.2508, 0.2393,
                   0.2344, 0.2353, 0.2371, 0.2525, 0.2736, 0.2827, 0.2819, 0.2812, 0.2661, 0.2499, 0.238
                   8, 0.2351, 0.2377, 0.2444, 0.2638, 0.2752, 0.2753, 0.2748, 0.2648, 0.2507, 0.2413, 0.2394, 0.24,
                   0.2437, 0.2598, 0.275, 0.2807, 0.2781, 0.2777, 0.2653, 0.2523, 0.2444, 0.2448, 0.246, 0.2597, 0.275,
                   0.2794, 0.2774, 0.2709, 0.2547, 0.2446, 0.2391, 0.239, 0.2403, 0.2527, 0.2755, 0.2831, 0.2799,
                   0.2768, 0.2645, 0.2533, 0.2487, 0.2486, 0.2508, 0.2621, 0.2756, 0.279, 0.278, 0.2703, 0.2565, 0.247,
                   0.2414, 0.2424, 0.2458, 0.2643, 0.2812, 0.2866, 0.2843]

# %%
def get_bpm(r_should):
    time_interval = []
    peak_index = ss.find_peaks(r_should, prominence=0.013)
    for i in range(len(peak_index[0]) - 1):
        second = (peak_index[0][i + 1] - peak_index[0][i]) / 21.8
        time_interval.append(second)
    seconds_avg = np.mean(time_interval)
    return (1 / seconds_avg) * 60


get_bpm(r_shoulder_data)
# Out:
# 128.10309278350516
